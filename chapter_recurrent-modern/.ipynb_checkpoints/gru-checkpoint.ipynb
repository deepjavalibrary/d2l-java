// %% [markdown]
// # Gated Recurrent Units (GRU)
// :label:`sec_gru`
//
// In :numref:`sec_bptt`,
// we discussed how gradients are calculated
// in RNNs.
// In particular we found that long products of matrices can lead
// to vanishing or exploding gradients.
// Let us briefly think about what such
// gradient anomalies mean in practice:
//
// * We might encounter a situation where an early observation is highly
//   significant for predicting all future observations. Consider the somewhat
//   contrived case where the first observation contains a checksum and the goal is
//   to discern whether the checksum is correct at the end of the sequence. In this
//   case, the influence of the first token is vital. We would like to have some
//   mechanisms for storing vital early information in a *memory cell*. Without such
//   a mechanism, we will have to assign a very large gradient to this observation,
//   since it affects all the subsequent observations.
// * We might encounter situations where some tokens carry no pertinent
//   observation. For instance, when parsing a web page there might be auxiliary
//   HTML code that is irrelevant for the purpose of assessing the sentiment
//   conveyed on the page. We would like to have some mechanism for *skipping* such
//   tokens in the latent state representation.
// * We might encounter situations where there is a logical break between parts of
//   a sequence. For instance, there might be a transition between chapters in a
//   book, or a transition between a bear and a bull market for securities. In
//   this case it would be nice to have a means of *resetting* our internal state
//   representation.
//
// A number of methods have been proposed to address this. One of the earliest is long short-term memory :cite:`Hochreiter.Schmidhuber.1997` which we
// will discuss in :numref:`sec_lstm`. The gated recurrent unit (GRU)
// :cite:`Cho.Van-Merrienboer.Bahdanau.ea.2014` is a slightly more streamlined
// variant that often offers comparable performance and is significantly faster to
// compute  :cite:`Chung.Gulcehre.Cho.ea.2014`.
// Due to its simplicity, let us start with the GRU.
//
// ## Gated Hidden State
//
// The key distinction between vanilla RNNs and GRUs
// is that the latter support gating of the hidden state.
// This means that we have dedicated mechanisms for
// when a hidden state should be *updated* and
// also when it should be *reset*.
// These mechanisms are learned and they address the concerns listed above.
// For instance, if the first token is of great importance
// we will learn not to update the hidden state after the first observation.
// Likewise, we will learn to skip irrelevant temporary observations.
// Last, we will learn to reset the latent state whenever needed.
// We discuss this in detail below.
//
//
// ### Reset Gate and Update Gate
//
// The first thing we need to introduce are
// the *reset gate* and the *update gate*.
// We engineer them to be vectors with entries in $(0, 1)$
// such that we can perform convex combinations.
// For instance,
// a reset gate would allow us to control how much of the previous state we might still want to remember.
// Likewise, an update gate would allow us to control how much of the new state is just a copy of the old state.
//
// We begin by engineering these gates.
// :numref:`fig_gru_1` illustrates the inputs for both
// the reset and update gates in a GRU, given the input
// of the current time step
// and the hidden state of the previous time step.
// The outputs of two gates
// are given by two fully-connected layers
// with a sigmoid activation function.
//
// ![Computing the reset gate and the update gate in a GRU model.](https://raw.githubusercontent.com/d2l-ai/d2l-en/master/img/gru-1.svg)
// :label:`fig_gru_1`
//
// Mathematically,
// for a given time step $t$,
// suppose that the input is
// a minibatch
// $\mathbf{X}_t \in \mathbb{R}^{n \times d}$ (number of examples: $n$, number of inputs: $d$) and the hidden state of the previous time step is $\mathbf{H}_{t-1} \in \mathbb{R}^{n \times h}$ (number of hidden units: $h$). Then, the reset gate $\mathbf{R}_t \in \mathbb{R}^{n \times h}$ and update gate $\mathbf{Z}_t \in \mathbb{R}^{n \times h}$ are computed as follows:
//
// $$
// \begin{aligned}
// \mathbf{R}_t = \sigma(\mathbf{X}_t \mathbf{W}_{xr} + \mathbf{H}_{t-1} \mathbf{W}_{hr} + \mathbf{b}_r),\\
// \mathbf{Z}_t = \sigma(\mathbf{X}_t \mathbf{W}_{xz} + \mathbf{H}_{t-1} \mathbf{W}_{hz} + \mathbf{b}_z),
// \end{aligned}
// $$
//
// where $\mathbf{W}_{xr}, \mathbf{W}_{xz} \in \mathbb{R}^{d \times h}$ and
// $\mathbf{W}_{hr}, \mathbf{W}_{hz} \in \mathbb{R}^{h \times h}$ are weight
// parameters and $\mathbf{b}_r, \mathbf{b}_z \in \mathbb{R}^{1 \times h}$ are
// biases.
// Note that broadcasting (see :numref:`subsec_broadcasting`) is triggered during the summation.
// We use sigmoid functions (as introduced in :numref:`sec_mlp`) to transform input values to the interval $(0, 1)$.
//
// ### Candidate Hidden State
//
// Next, let us
// integrate the reset gate $\mathbf{R}_t$ with
// the regular latent state updating mechanism
// in :eqref:`rnn_h_with_state`.
// It leads to the following
// *candidate hidden state*
// $\tilde{\mathbf{H}}_t \in \mathbb{R}^{n \times h}$ at time step $t$:
//
// $$\tilde{\mathbf{H}}_t = \tanh(\mathbf{X}_t \mathbf{W}_{xh} + \left(\mathbf{R}_t \odot \mathbf{H}_{t-1}\right) \mathbf{W}_{hh} + \mathbf{b}_h),$$
// :eqlabel:`gru_tilde_H`
//
// where $\mathbf{W}_{xh} \in \mathbb{R}^{d \times h}$ and $\mathbf{W}_{hh} \in \mathbb{R}^{h \times h}$
// are weight parameters,
// $\mathbf{b}_h \in \mathbb{R}^{1 \times h}$
// is the bias,
// and the symbol $\odot$ is the Hadamard (elementwise) product operator.
// Here we use a nonlinearity in the form of tanh to ensure that the values in the candidate hidden state remain in the interval $(-1, 1)$.
//
// The result is a *candidate* since we still need to incorporate the action of the update gate.
// Comparing with :eqref:`rnn_h_with_state`,
// now the influence of the previous states
// can be reduced with the
// elementwise multiplication of
// $\mathbf{R}_t$ and $\mathbf{H}_{t-1}$
// in :eqref:`gru_tilde_H`.
// Whenever the entries in the reset gate $\mathbf{R}_t$ are close to 1, we recover a vanilla RNN such as in :eqref:`rnn_h_with_state`.
// For all entries of the reset gate $\mathbf{R}_t$ that are close to 0, the candidate hidden state is the result of an MLP with $\mathbf{X}_t$ as the input. Any pre-existing hidden state is thus *reset* to defaults.
//
// :numref:`fig_gru_2` illustrates the computational flow after applying the reset gate.
//
// ![Computing the candidate hidden state in a GRU model.](https://raw.githubusercontent.com/d2l-ai/d2l-en/master/img/gru-2.svg)
// :label:`fig_gru_2`
//
//
// ### Hidden State
//
// Finally, we need to incorporate the effect of the update gate $\mathbf{Z}_t$. This determines the extent to which the new hidden state $\mathbf{H}_t \in \mathbb{R}^{n \times h}$ is just the old state $\mathbf{H}_{t-1}$ and by how much the new candidate state $\tilde{\mathbf{H}}_t$ is used.
// The update gate $\mathbf{Z}_t$ can be used for this purpose, simply by taking elementwise convex combinations between both $\mathbf{H}_{t-1}$ and $\tilde{\mathbf{H}}_t$.
// This leads to the final update equation for the GRU:
//
// $$\mathbf{H}_t = \mathbf{Z}_t \odot \mathbf{H}_{t-1}  + (1 - \mathbf{Z}_t) \odot \tilde{\mathbf{H}}_t.$$
//
//
// Whenever the update gate $\mathbf{Z}_t$ is close to 1, we simply retain the old state. In this case the information from $\mathbf{X}_t$ is essentially ignored, effectively skipping time step $t$ in the dependency chain. In contrast, whenever $\mathbf{Z}_t$ is close to 0, the new latent state $\mathbf{H}_t$ approaches the candidate latent state $\tilde{\mathbf{H}}_t$. These designs can help us cope with the vanishing gradient problem in RNNs and better capture dependencies for sequences with large time step distances.
// For instance,
// if the update gate has been close to 1
// for all the time steps of an entire subsequence,
// the old hidden state at the time step of its beginning
// will be easily retained and passed
// to its end,
// regardless of the length of the subsequence.
//
//
//
// :numref:`fig_gru_3` illustrates the computational flow after the update gate is in action.
//
// ![Computing the hidden state in a GRU model.](https://raw.githubusercontent.com/d2l-ai/d2l-en/master/img/gru-3.svg)
// :label:`fig_gru_3`
//
//
// In summary, GRUs have the following two distinguishing features:
//
// * Reset gates help capture short-term dependencies in sequences.
// * Update gates help capture long-term dependencies in sequences.
//
// ## Implementation from Scratch
//
// To gain a better understanding of the GRU model, let us implement it from scratch. We begin by reading the time machine dataset that we used in :numref:`sec_rnn_scratch`. The code for reading the dataset is given below.

// %%
%mavenRepo snapshots https://oss.sonatype.org/content/repositories/snapshots/
%maven org.slf4j:slf4j-api:1.7.26
%maven org.slf4j:slf4j-simple:1.7.26
    
%maven ai.djl:api:0.11.0-SNAPSHOT
%maven ai.djl:basicdataset:0.11.0-SNAPSHOT

// See https://github.com/awslabs/djl/blob/master/mxnet/mxnet-engine/README.md
// MXNet 
%maven ai.djl.mxnet:mxnet-engine:0.11.0-SNAPSHOT
%maven ai.djl.mxnet:mxnet-native-auto:1.7.0-backport

// %%
%load ../utils/plot-utils
%load ../utils/Functions.java
%load ../utils/PlotUtils.java

%load ../utils/StopWatch.java
%load ../utils/Accumulator.java
%load ../utils/Animator.java
%load ../utils/Training.java
%load ../utils/TimeMachineUtils.java

// %%
NDManager manager = NDManager.newBaseManager(Functions.tryGpu(0));

// %%
int batchSize = 32;
int numSteps = 35;

TimeMachineDataset dataset =
        new TimeMachineDataset.Builder()
                .setManager(manager)
                .setMaxTokens(10000)
                .setSampling(batchSize, false)
                .setSteps(numSteps)
                .build();
dataset.prepare();
Vocab vocab = dataset.getVocab();

// %% [markdown]
// ### Initializing Model Parameters
//
// The next step is to initialize the model parameters.
// We draw the weights from a Gaussian distribution
// with standard deviation to be 0.01 and set the bias to 0. The hyperparameter `num_hiddens` defines the number of hidden units.
// We instantiate all weights and biases relating to the update gate, the reset gate, the candidate hidden state,
// and the output layer.

// %%
public static NDArray normal(Shape shape, Device device) {
    return manager.randomNormal(0, 0.01f, shape, DataType.FLOAT32, device);
}

public static NDList three(int numInputs, int numHiddens, Device device) {
    return new NDList(
            normal(new Shape(numInputs, numHiddens), device),
            normal(new Shape(numHiddens, numHiddens), device),
            manager.zeros(new Shape(numHiddens), DataType.FLOAT32, device));
}

public static NDList getParams(int vocabSize, int numHiddens, Device device) {
    int numInputs = vocabSize;
    int numOutputs = vocabSize;

    // Update gate parameters
    NDList temp = three(numInputs, numHiddens, device);
    NDArray W_xz = temp.get(0);
    NDArray W_hz = temp.get(1);
    NDArray b_z = temp.get(2);

    // Reset gate parameters
    temp = three(numInputs, numHiddens, device);
    NDArray W_xr = temp.get(0);
    NDArray W_hr = temp.get(1);
    NDArray b_r = temp.get(2);

    // Candidate hidden state parameters
    temp = three(numInputs, numHiddens, device);
    NDArray W_xh = temp.get(0);
    NDArray W_hh = temp.get(1);
    NDArray b_h = temp.get(2);

    // Output layer parameters
    NDArray W_hq = normal(new Shape(numHiddens, numOutputs), device);
    NDArray b_q = manager.zeros(new Shape(numOutputs), DataType.FLOAT32, device);

    // Attach gradients
    NDList params = new NDList(W_xz, W_hz, b_z, W_xr, W_hr, b_r, W_xh, W_hh, b_h, W_hq, b_q);
    for (NDArray param : params) {
        param.attachGradient();
    }
    return params;
}

// %% [markdown]
// ### Defining the Model
//
// Now we will define the hidden state initialization function `init_gru_state`. Just like the `init_rnn_state` function defined in :numref:`sec_rnn_scratch`, this function returns a tensor with a shape (batch size, number of hidden units) whose values are all zeros.

// %%
public static NDList initGruState(int batchSize, int numHiddens, Device device) {
    return new NDList(manager.zeros(new Shape(batchSize, numHiddens), DataType.FLOAT32, device));
}

// %% [markdown]
// Now we are ready to define the GRU model.
// Its structure is the same as that of the basic RNN cell, except that the update equations are more complex.

// %%
public static Pair<NDArray, NDList> gru(NDArray inputs, NDList state, NDList params) {
    NDArray W_xz = params.get(0);
    NDArray W_hz = params.get(1);
    NDArray b_z = params.get(2);

    NDArray W_xr = params.get(3);
    NDArray W_hr = params.get(4);
    NDArray b_r = params.get(5);

    NDArray W_xh = params.get(6);
    NDArray W_hh = params.get(7);
    NDArray b_h = params.get(8);

    NDArray W_hq = params.get(9);
    NDArray b_q  = params.get(10);

    NDArray H = state.get(0);
    NDList outputs = new NDList();
    NDArray X, Y;
    for (int i = 0; i < inputs.size(0); i++) {
        X = inputs.get(i);
        NDArray Z = Activation.sigmoid(X.dot(W_xz).add(H.dot(W_hz).add(b_z)));
        NDArray R = Activation.sigmoid(X.dot(W_xr).add(H.dot(W_hr).add(b_r)));
        NDArray H_tilda = Activation.tanh(X.dot(W_xh).add(R.mul(H).dot(W_hh).add(b_h)));
        H = Z.mul(H).add(Z.mul(-1).add(1).mul(H_tilda));
        Y = H.dot(W_hq).add(b_q);
        outputs.add(Y);
    }
    return new Pair(outputs.size() > 1 ? NDArrays.concat(outputs) : outputs.get(0), new NDList(H));
}

// %% [markdown]
// ### Training and Prediction
//
// Training and prediction work in exactly the same manner as in :numref:`sec_rnn_scratch`.
// After training,
// we print out the perplexity on the training set
// and the predicted sequence following
// the provided prefixes "time traveller" and "traveller", respectively.

// %%
int vocabSize = vocab.length();
int numHiddens = 256;
Device device = Functions.tryGpu(0);
int numEpochs = 500;
int lr = 1;

Functions.TriFunction<Integer, Integer, Device, NDList> getParamsFn = (a, b, c) -> getParams(a, b, c);
Functions.TriFunction<Integer, Integer, Device, NDList> initGruStateFn =
        (a, b, c) -> initGruState(a, b, c);
Functions.TriFunction<NDArray, NDList, NDList, Pair> gruFn = (a, b, c) -> gru(a, b, c);

RNNModelScratch model =
        new RNNModelScratch(vocabSize, numHiddens, device,
                getParamsFn, initGruStateFn, gruFn);
//TimeMachine.trainCh8(model, dataset, vocab, lr, numEpochs, device, false, manager);

// %% [markdown]
// ## Concise Implementation
//
// In high-level APIs,
// we can directly
// instantiate a GPU model.
// This encapsulates all the configuration detail that we made explicit above.
// The code is significantly faster as it uses compiled operators rather than Python for many details that we spelled out before.

// %%
GRU gruLayer = GRU.builder().setNumLayers(1)
        .setStateSize(numHiddens).optReturnState(true).optBatchFirst(false).build();
RNNModel modelConcise = new RNNModel(gruLayer,vocab.length());
TimeMachine.trainCh8(model, dataset, vocab, lr, numEpochs, device, false, manager);
// Out:
// epoch: 0, perplexity: 24.9, 9017.1 tokens/sec on cpu()
// epoch: 1, perplexity: 20.9, 10285.5 tokens/sec on cpu()
// epoch: 2, perplexity: 19.1, 10805.3 tokens/sec on cpu()
// epoch: 3, perplexity: 18.2, 11250.8 tokens/sec on cpu()
// epoch: 4, perplexity: 17.8, 11197.6 tokens/sec on cpu()
// epoch: 5, perplexity: 17.6, 11075.2 tokens/sec on cpu()
// epoch: 6, perplexity: 17.5, 10929.3 tokens/sec on cpu()
// epoch: 7, perplexity: 17.4, 11258.1 tokens/sec on cpu()
// epoch: 8, perplexity: 17.3, 11195.1 tokens/sec on cpu()
// epoch: 9, perplexity: 17.2, 10293.0 tokens/sec on cpu()
// epoch: 10, perplexity: 17.1, 10775.0 tokens/sec on cpu()
// epoch: 11, perplexity: 17.0, 10978.5 tokens/sec on cpu()
// epoch: 12, perplexity: 16.9, 11353.6 tokens/sec on cpu()
// epoch: 13, perplexity: 16.7, 11344.3 tokens/sec on cpu()
// epoch: 14, perplexity: 16.5, 11080.7 tokens/sec on cpu()
// epoch: 15, perplexity: 16.3, 11305.2 tokens/sec on cpu()
// epoch: 16, perplexity: 16.1, 11444.7 tokens/sec on cpu()
// epoch: 17, perplexity: 15.9, 10464.1 tokens/sec on cpu()
// epoch: 18, perplexity: 15.7, 11191.0 tokens/sec on cpu()
// epoch: 19, perplexity: 15.5, 11093.9 tokens/sec on cpu()
// epoch: 20, perplexity: 15.3, 8866.0 tokens/sec on cpu()
// epoch: 21, perplexity: 15.0, 10224.2 tokens/sec on cpu()
// epoch: 22, perplexity: 14.8, 9896.5 tokens/sec on cpu()
// epoch: 23, perplexity: 14.5, 10130.7 tokens/sec on cpu()
// epoch: 24, perplexity: 14.2, 10528.3 tokens/sec on cpu()
// epoch: 25, perplexity: 14.0, 11479.6 tokens/sec on cpu()
// epoch: 26, perplexity: 13.7, 11423.6 tokens/sec on cpu()
// epoch: 27, perplexity: 13.4, 11483.9 tokens/sec on cpu()
// epoch: 28, perplexity: 13.2, 11510.5 tokens/sec on cpu()
// epoch: 29, perplexity: 12.9, 10431.0 tokens/sec on cpu()
// epoch: 30, perplexity: 12.7, 10591.4 tokens/sec on cpu()
// epoch: 31, perplexity: 12.5, 11490.7 tokens/sec on cpu()
// epoch: 32, perplexity: 12.3, 11469.9 tokens/sec on cpu()
// epoch: 33, perplexity: 12.2, 11538.4 tokens/sec on cpu()
// epoch: 34, perplexity: 12.0, 11499.0 tokens/sec on cpu()
// epoch: 35, perplexity: 11.9, 11291.2 tokens/sec on cpu()
// epoch: 36, perplexity: 11.8, 11305.7 tokens/sec on cpu()
// epoch: 37, perplexity: 11.7, 11341.3 tokens/sec on cpu()
// epoch: 38, perplexity: 11.6, 11542.2 tokens/sec on cpu()
// epoch: 39, perplexity: 11.5, 11469.1 tokens/sec on cpu()
// epoch: 40, perplexity: 11.4, 11500.8 tokens/sec on cpu()
// epoch: 41, perplexity: 11.4, 9958.5 tokens/sec on cpu()
// epoch: 42, perplexity: 11.3, 8915.1 tokens/sec on cpu()
// epoch: 43, perplexity: 11.2, 8231.8 tokens/sec on cpu()
// epoch: 44, perplexity: 11.2, 9447.1 tokens/sec on cpu()
// epoch: 45, perplexity: 11.1, 9255.9 tokens/sec on cpu()
// epoch: 46, perplexity: 11.0, 8203.4 tokens/sec on cpu()
// epoch: 47, perplexity: 11.0, 9750.8 tokens/sec on cpu()
// epoch: 48, perplexity: 10.9, 9005.2 tokens/sec on cpu()
// epoch: 49, perplexity: 10.9, 9635.2 tokens/sec on cpu()
// epoch: 50, perplexity: 10.8, 10801.1 tokens/sec on cpu()
// epoch: 51, perplexity: 10.8, 10727.7 tokens/sec on cpu()
// epoch: 52, perplexity: 10.7, 7688.6 tokens/sec on cpu()
// epoch: 53, perplexity: 10.7, 9333.8 tokens/sec on cpu()
// epoch: 54, perplexity: 10.6, 9094.7 tokens/sec on cpu()
// epoch: 55, perplexity: 10.6, 9535.9 tokens/sec on cpu()
// epoch: 56, perplexity: 10.5, 8223.9 tokens/sec on cpu()
// epoch: 57, perplexity: 10.5, 9317.5 tokens/sec on cpu()
// epoch: 58, perplexity: 10.4, 6888.2 tokens/sec on cpu()
// epoch: 59, perplexity: 10.4, 7481.4 tokens/sec on cpu()
// epoch: 60, perplexity: 10.3, 7837.3 tokens/sec on cpu()
// epoch: 61, perplexity: 10.3, 6345.5 tokens/sec on cpu()
// epoch: 62, perplexity: 10.3, 6244.0 tokens/sec on cpu()
// epoch: 63, perplexity: 10.2, 6539.8 tokens/sec on cpu()
// epoch: 64, perplexity: 10.2, 9797.4 tokens/sec on cpu()
// epoch: 65, perplexity: 10.2, 9586.0 tokens/sec on cpu()
// epoch: 66, perplexity: 10.1, 9968.8 tokens/sec on cpu()
// epoch: 67, perplexity: 10.1, 9886.1 tokens/sec on cpu()
// epoch: 68, perplexity: 10.1, 8959.8 tokens/sec on cpu()
// epoch: 69, perplexity: 10.0, 10244.4 tokens/sec on cpu()
// epoch: 70, perplexity: 10.0, 6178.9 tokens/sec on cpu()
// epoch: 71, perplexity: 9.9, 8095.5 tokens/sec on cpu()
// epoch: 72, perplexity: 9.9, 10158.9 tokens/sec on cpu()
// epoch: 73, perplexity: 9.9, 10341.7 tokens/sec on cpu()
// epoch: 74, perplexity: 9.8, 9947.8 tokens/sec on cpu()
// epoch: 75, perplexity: 9.8, 10888.7 tokens/sec on cpu()
// epoch: 76, perplexity: 9.8, 10197.0 tokens/sec on cpu()
// epoch: 77, perplexity: 9.7, 8097.2 tokens/sec on cpu()
// epoch: 78, perplexity: 9.7, 9588.8 tokens/sec on cpu()
// epoch: 79, perplexity: 9.7, 9413.4 tokens/sec on cpu()
// epoch: 80, perplexity: 9.6, 8531.0 tokens/sec on cpu()
// epoch: 81, perplexity: 9.6, 9302.5 tokens/sec on cpu()
// epoch: 82, perplexity: 9.6, 8804.6 tokens/sec on cpu()
// epoch: 83, perplexity: 9.5, 8303.7 tokens/sec on cpu()
// epoch: 84, perplexity: 9.5, 10640.3 tokens/sec on cpu()
// epoch: 85, perplexity: 9.5, 11035.6 tokens/sec on cpu()
// epoch: 86, perplexity: 9.4, 10876.1 tokens/sec on cpu()
// epoch: 87, perplexity: 9.4, 10559.7 tokens/sec on cpu()
// epoch: 88, perplexity: 9.4, 11606.4 tokens/sec on cpu()
// epoch: 89, perplexity: 9.3, 11423.4 tokens/sec on cpu()
// epoch: 90, perplexity: 9.3, 10142.5 tokens/sec on cpu()
// epoch: 91, perplexity: 9.3, 10041.2 tokens/sec on cpu()
// epoch: 92, perplexity: 9.2, 8779.7 tokens/sec on cpu()
// epoch: 93, perplexity: 9.2, 10801.0 tokens/sec on cpu()
// epoch: 94, perplexity: 9.2, 10637.3 tokens/sec on cpu()
// epoch: 95, perplexity: 9.1, 11106.6 tokens/sec on cpu()
// epoch: 96, perplexity: 9.1, 11147.6 tokens/sec on cpu()
// epoch: 97, perplexity: 9.1, 11269.5 tokens/sec on cpu()
// epoch: 98, perplexity: 9.0, 11372.3 tokens/sec on cpu()
// epoch: 99, perplexity: 9.0, 11179.7 tokens/sec on cpu()
// epoch: 100, perplexity: 9.0, 11333.8 tokens/sec on cpu()
// epoch: 101, perplexity: 8.9, 9540.0 tokens/sec on cpu()
// epoch: 102, perplexity: 8.9, 8866.4 tokens/sec on cpu()
// epoch: 103, perplexity: 8.9, 9301.5 tokens/sec on cpu()
// epoch: 104, perplexity: 8.8, 8320.1 tokens/sec on cpu()
// epoch: 105, perplexity: 8.8, 6466.9 tokens/sec on cpu()
// epoch: 106, perplexity: 8.8, 9070.3 tokens/sec on cpu()
// epoch: 107, perplexity: 8.7, 11283.9 tokens/sec on cpu()
// epoch: 108, perplexity: 8.7, 8626.6 tokens/sec on cpu()
// epoch: 109, perplexity: 8.7, 8711.1 tokens/sec on cpu()
// epoch: 110, perplexity: 8.7, 9062.2 tokens/sec on cpu()
// epoch: 111, perplexity: 8.6, 7510.7 tokens/sec on cpu()
// epoch: 112, perplexity: 8.6, 6547.5 tokens/sec on cpu()
// epoch: 113, perplexity: 8.6, 5818.4 tokens/sec on cpu()
// epoch: 114, perplexity: 8.5, 6040.7 tokens/sec on cpu()
// epoch: 115, perplexity: 8.5, 8619.1 tokens/sec on cpu()
// epoch: 116, perplexity: 8.5, 9018.0 tokens/sec on cpu()
// epoch: 117, perplexity: 8.4, 9494.3 tokens/sec on cpu()
// epoch: 118, perplexity: 8.4, 8192.0 tokens/sec on cpu()
// epoch: 119, perplexity: 8.4, 9583.8 tokens/sec on cpu()
// epoch: 120, perplexity: 8.3, 8883.9 tokens/sec on cpu()
// epoch: 121, perplexity: 8.3, 9722.8 tokens/sec on cpu()
// epoch: 122, perplexity: 8.3, 10328.0 tokens/sec on cpu()
// epoch: 123, perplexity: 8.3, 11241.9 tokens/sec on cpu()
// epoch: 124, perplexity: 8.2, 9162.6 tokens/sec on cpu()
// epoch: 125, perplexity: 8.2, 7059.4 tokens/sec on cpu()
// epoch: 126, perplexity: 8.2, 8415.4 tokens/sec on cpu()
// epoch: 127, perplexity: 8.1, 10128.5 tokens/sec on cpu()
// epoch: 128, perplexity: 8.1, 8680.6 tokens/sec on cpu()
// epoch: 129, perplexity: 8.1, 8534.0 tokens/sec on cpu()
// epoch: 130, perplexity: 8.1, 6402.8 tokens/sec on cpu()
// epoch: 131, perplexity: 8.0, 8261.0 tokens/sec on cpu()
// epoch: 132, perplexity: 8.0, 8652.5 tokens/sec on cpu()
// epoch: 133, perplexity: 8.0, 11068.9 tokens/sec on cpu()
// epoch: 134, perplexity: 8.0, 11492.6 tokens/sec on cpu()
// epoch: 135, perplexity: 7.9, 11437.4 tokens/sec on cpu()
// epoch: 136, perplexity: 7.9, 11305.0 tokens/sec on cpu()
// epoch: 137, perplexity: 7.9, 11490.0 tokens/sec on cpu()
// epoch: 138, perplexity: 7.8, 11634.8 tokens/sec on cpu()
// epoch: 139, perplexity: 7.8, 11503.0 tokens/sec on cpu()
// epoch: 140, perplexity: 7.8, 11208.2 tokens/sec on cpu()
// epoch: 141, perplexity: 7.8, 11556.7 tokens/sec on cpu()
// epoch: 142, perplexity: 7.7, 11365.9 tokens/sec on cpu()
// epoch: 143, perplexity: 7.7, 10896.0 tokens/sec on cpu()
// epoch: 144, perplexity: 7.7, 9067.5 tokens/sec on cpu()
// epoch: 145, perplexity: 7.7, 8942.4 tokens/sec on cpu()
// epoch: 146, perplexity: 7.6, 9793.4 tokens/sec on cpu()
// epoch: 147, perplexity: 7.6, 10730.0 tokens/sec on cpu()
// epoch: 148, perplexity: 7.6, 11049.1 tokens/sec on cpu()
// epoch: 149, perplexity: 7.5, 9787.8 tokens/sec on cpu()
// epoch: 150, perplexity: 7.5, 7560.8 tokens/sec on cpu()
// epoch: 151, perplexity: 7.5, 9862.2 tokens/sec on cpu()
// epoch: 152, perplexity: 7.4, 9866.9 tokens/sec on cpu()
// epoch: 153, perplexity: 7.4, 9484.6 tokens/sec on cpu()
// epoch: 154, perplexity: 7.4, 9468.1 tokens/sec on cpu()
// epoch: 155, perplexity: 7.4, 11223.0 tokens/sec on cpu()
// epoch: 156, perplexity: 7.4, 11474.9 tokens/sec on cpu()
// epoch: 157, perplexity: 7.3, 11257.1 tokens/sec on cpu()
// epoch: 158, perplexity: 7.3, 11499.5 tokens/sec on cpu()
// epoch: 159, perplexity: 7.3, 11191.2 tokens/sec on cpu()
// epoch: 160, perplexity: 7.2, 11475.7 tokens/sec on cpu()
// epoch: 161, perplexity: 7.2, 11373.4 tokens/sec on cpu()
// epoch: 162, perplexity: 7.2, 11100.5 tokens/sec on cpu()
// epoch: 163, perplexity: 7.1, 10103.0 tokens/sec on cpu()
// epoch: 164, perplexity: 7.2, 11439.6 tokens/sec on cpu()
// epoch: 165, perplexity: 7.1, 11557.5 tokens/sec on cpu()
// epoch: 166, perplexity: 7.1, 11406.3 tokens/sec on cpu()
// epoch: 167, perplexity: 7.1, 11157.2 tokens/sec on cpu()
// epoch: 168, perplexity: 7.0, 11509.6 tokens/sec on cpu()
// epoch: 169, perplexity: 7.0, 10801.0 tokens/sec on cpu()
// epoch: 170, perplexity: 7.0, 11319.4 tokens/sec on cpu()
// epoch: 171, perplexity: 6.9, 11287.3 tokens/sec on cpu()
// epoch: 172, perplexity: 6.9, 11282.7 tokens/sec on cpu()
// epoch: 173, perplexity: 6.9, 11432.3 tokens/sec on cpu()
// epoch: 174, perplexity: 7.0, 11437.5 tokens/sec on cpu()
// epoch: 175, perplexity: 6.8, 10760.2 tokens/sec on cpu()
// epoch: 176, perplexity: 6.7, 10727.4 tokens/sec on cpu()
// epoch: 177, perplexity: 6.8, 11401.2 tokens/sec on cpu()
// epoch: 178, perplexity: 6.7, 11364.8 tokens/sec on cpu()
// epoch: 179, perplexity: 6.7, 9612.0 tokens/sec on cpu()
// epoch: 180, perplexity: 6.7, 10615.5 tokens/sec on cpu()
// epoch: 181, perplexity: 6.6, 10977.2 tokens/sec on cpu()
// epoch: 182, perplexity: 6.6, 11170.2 tokens/sec on cpu()
// epoch: 183, perplexity: 6.6, 11511.7 tokens/sec on cpu()
// epoch: 184, perplexity: 6.6, 11346.3 tokens/sec on cpu()
// epoch: 185, perplexity: 6.5, 11271.1 tokens/sec on cpu()
// epoch: 186, perplexity: 6.5, 11279.6 tokens/sec on cpu()
// epoch: 187, perplexity: 6.6, 11214.5 tokens/sec on cpu()
// epoch: 188, perplexity: 6.4, 11432.7 tokens/sec on cpu()
// epoch: 189, perplexity: 6.4, 11200.4 tokens/sec on cpu()
// epoch: 190, perplexity: 6.4, 11272.0 tokens/sec on cpu()
// epoch: 191, perplexity: 6.4, 11496.6 tokens/sec on cpu()
// epoch: 192, perplexity: 6.4, 11282.5 tokens/sec on cpu()
// epoch: 193, perplexity: 6.4, 11476.3 tokens/sec on cpu()
// epoch: 194, perplexity: 6.3, 10875.5 tokens/sec on cpu()
// epoch: 195, perplexity: 6.3, 10195.7 tokens/sec on cpu()
// epoch: 196, perplexity: 6.2, 11132.0 tokens/sec on cpu()
// epoch: 197, perplexity: 6.2, 11195.8 tokens/sec on cpu()
// epoch: 198, perplexity: 6.2, 10174.4 tokens/sec on cpu()
// epoch: 199, perplexity: 6.3, 9300.5 tokens/sec on cpu()
// epoch: 200, perplexity: 6.2, 9349.4 tokens/sec on cpu()
// epoch: 201, perplexity: 6.1, 7023.0 tokens/sec on cpu()
// epoch: 202, perplexity: 6.0, 7161.3 tokens/sec on cpu()
// epoch: 203, perplexity: 6.0, 6850.1 tokens/sec on cpu()
// epoch: 204, perplexity: 6.1, 8861.6 tokens/sec on cpu()
// epoch: 205, perplexity: 6.0, 9085.3 tokens/sec on cpu()
// epoch: 206, perplexity: 6.1, 9847.6 tokens/sec on cpu()
// epoch: 207, perplexity: 5.9, 10943.1 tokens/sec on cpu()
// epoch: 208, perplexity: 5.9, 10823.8 tokens/sec on cpu()
// epoch: 209, perplexity: 5.9, 10558.4 tokens/sec on cpu()
// epoch: 210, perplexity: 5.9, 11374.6 tokens/sec on cpu()
// epoch: 211, perplexity: 5.9, 10142.7 tokens/sec on cpu()
// epoch: 212, perplexity: 5.8, 10350.2 tokens/sec on cpu()
// epoch: 213, perplexity: 5.8, 10567.8 tokens/sec on cpu()
// epoch: 214, perplexity: 5.8, 11195.2 tokens/sec on cpu()
// epoch: 215, perplexity: 5.7, 11158.7 tokens/sec on cpu()
// epoch: 216, perplexity: 5.7, 11279.3 tokens/sec on cpu()
// epoch: 217, perplexity: 5.7, 10921.8 tokens/sec on cpu()
// epoch: 218, perplexity: 5.7, 11001.5 tokens/sec on cpu()
// epoch: 219, perplexity: 5.7, 10223.0 tokens/sec on cpu()
// epoch: 220, perplexity: 5.6, 10038.6 tokens/sec on cpu()
// epoch: 221, perplexity: 5.5, 8643.0 tokens/sec on cpu()
// epoch: 222, perplexity: 5.6, 6101.4 tokens/sec on cpu()
// epoch: 223, perplexity: 5.5, 8096.5 tokens/sec on cpu()
// epoch: 224, perplexity: 5.4, 8173.7 tokens/sec on cpu()
// epoch: 225, perplexity: 5.4, 9445.2 tokens/sec on cpu()
// epoch: 226, perplexity: 5.4, 9447.8 tokens/sec on cpu()
// epoch: 227, perplexity: 5.4, 5994.1 tokens/sec on cpu()
// epoch: 228, perplexity: 5.3, 8028.5 tokens/sec on cpu()
// epoch: 229, perplexity: 5.3, 8585.3 tokens/sec on cpu()
// epoch: 230, perplexity: 5.3, 6286.1 tokens/sec on cpu()
// epoch: 231, perplexity: 5.2, 7104.3 tokens/sec on cpu()
// epoch: 232, perplexity: 5.1, 6622.5 tokens/sec on cpu()
// epoch: 233, perplexity: 5.2, 6182.5 tokens/sec on cpu()
// epoch: 234, perplexity: 5.1, 8391.3 tokens/sec on cpu()
// epoch: 235, perplexity: 5.1, 8894.9 tokens/sec on cpu()
// epoch: 236, perplexity: 5.0, 7354.0 tokens/sec on cpu()
// epoch: 237, perplexity: 5.1, 7627.5 tokens/sec on cpu()
// epoch: 238, perplexity: 5.0, 8927.3 tokens/sec on cpu()
// epoch: 239, perplexity: 5.0, 9437.0 tokens/sec on cpu()
// epoch: 240, perplexity: 5.0, 6509.2 tokens/sec on cpu()
// epoch: 241, perplexity: 4.9, 9158.3 tokens/sec on cpu()
// epoch: 242, perplexity: 4.9, 9708.8 tokens/sec on cpu()
// epoch: 243, perplexity: 4.8, 9867.3 tokens/sec on cpu()
// epoch: 244, perplexity: 4.8, 10201.5 tokens/sec on cpu()
// epoch: 245, perplexity: 4.8, 9852.9 tokens/sec on cpu()
// epoch: 246, perplexity: 4.8, 8413.5 tokens/sec on cpu()
// epoch: 247, perplexity: 4.7, 7456.2 tokens/sec on cpu()
// epoch: 248, perplexity: 4.7, 8326.5 tokens/sec on cpu()
// epoch: 249, perplexity: 4.6, 8009.5 tokens/sec on cpu()
// epoch: 250, perplexity: 4.7, 8393.9 tokens/sec on cpu()
// epoch: 251, perplexity: 4.5, 9011.5 tokens/sec on cpu()
// epoch: 252, perplexity: 4.5, 9469.2 tokens/sec on cpu()
// epoch: 253, perplexity: 4.5, 9437.6 tokens/sec on cpu()
// epoch: 254, perplexity: 4.5, 8592.8 tokens/sec on cpu()
// epoch: 255, perplexity: 4.4, 9698.2 tokens/sec on cpu()
// epoch: 256, perplexity: 4.5, 10755.7 tokens/sec on cpu()
// epoch: 257, perplexity: 4.4, 10912.0 tokens/sec on cpu()
// epoch: 258, perplexity: 4.4, 9171.4 tokens/sec on cpu()
// epoch: 259, perplexity: 4.2, 9244.2 tokens/sec on cpu()
// epoch: 260, perplexity: 4.3, 9601.9 tokens/sec on cpu()
// epoch: 261, perplexity: 4.2, 9939.2 tokens/sec on cpu()
// epoch: 262, perplexity: 4.2, 9555.0 tokens/sec on cpu()
// epoch: 263, perplexity: 4.1, 9623.5 tokens/sec on cpu()
// epoch: 264, perplexity: 4.2, 9730.9 tokens/sec on cpu()
// epoch: 265, perplexity: 4.2, 8571.4 tokens/sec on cpu()
// epoch: 266, perplexity: 4.1, 9651.0 tokens/sec on cpu()
// epoch: 267, perplexity: 4.0, 9086.3 tokens/sec on cpu()
// epoch: 268, perplexity: 4.0, 8993.2 tokens/sec on cpu()
// epoch: 269, perplexity: 4.0, 10158.8 tokens/sec on cpu()
// epoch: 270, perplexity: 3.9, 9657.3 tokens/sec on cpu()
// epoch: 271, perplexity: 3.9, 11284.9 tokens/sec on cpu()
// epoch: 272, perplexity: 4.0, 9832.0 tokens/sec on cpu()
// epoch: 273, perplexity: 3.8, 10247.5 tokens/sec on cpu()
// epoch: 274, perplexity: 3.7, 10107.5 tokens/sec on cpu()
// epoch: 275, perplexity: 3.8, 11286.0 tokens/sec on cpu()
// epoch: 276, perplexity: 3.6, 11418.8 tokens/sec on cpu()
// epoch: 277, perplexity: 3.7, 10965.1 tokens/sec on cpu()
// epoch: 278, perplexity: 3.7, 11335.4 tokens/sec on cpu()
// epoch: 279, perplexity: 3.6, 11411.2 tokens/sec on cpu()
// epoch: 280, perplexity: 3.5, 11361.6 tokens/sec on cpu()
// epoch: 281, perplexity: 3.4, 11339.2 tokens/sec on cpu()
// epoch: 282, perplexity: 3.6, 11378.3 tokens/sec on cpu()
// epoch: 283, perplexity: 3.4, 11195.2 tokens/sec on cpu()
// epoch: 284, perplexity: 3.4, 11380.4 tokens/sec on cpu()
// epoch: 285, perplexity: 3.3, 11337.4 tokens/sec on cpu()
// epoch: 286, perplexity: 3.3, 11284.0 tokens/sec on cpu()
// epoch: 287, perplexity: 3.4, 11441.4 tokens/sec on cpu()
// epoch: 288, perplexity: 3.2, 11543.3 tokens/sec on cpu()
// epoch: 289, perplexity: 3.1, 11368.3 tokens/sec on cpu()
// epoch: 290, perplexity: 3.2, 10314.7 tokens/sec on cpu()
// epoch: 291, perplexity: 3.1, 10295.2 tokens/sec on cpu()
// epoch: 292, perplexity: 3.1, 11160.8 tokens/sec on cpu()
// epoch: 293, perplexity: 3.1, 11544.6 tokens/sec on cpu()
// epoch: 294, perplexity: 3.0, 11669.3 tokens/sec on cpu()
// epoch: 295, perplexity: 3.0, 11588.1 tokens/sec on cpu()
// epoch: 296, perplexity: 2.9, 11421.0 tokens/sec on cpu()
// epoch: 297, perplexity: 2.8, 11078.5 tokens/sec on cpu()
// epoch: 298, perplexity: 2.9, 10864.6 tokens/sec on cpu()
// epoch: 299, perplexity: 2.9, 10735.8 tokens/sec on cpu()
// epoch: 300, perplexity: 2.8, 11568.0 tokens/sec on cpu()
// epoch: 301, perplexity: 2.7, 9762.8 tokens/sec on cpu()
// epoch: 302, perplexity: 2.6, 9866.2 tokens/sec on cpu()
// epoch: 303, perplexity: 2.7, 8230.2 tokens/sec on cpu()
// epoch: 304, perplexity: 2.6, 8640.1 tokens/sec on cpu()
// epoch: 305, perplexity: 2.8, 8830.7 tokens/sec on cpu()
// epoch: 306, perplexity: 2.5, 10924.4 tokens/sec on cpu()
// epoch: 307, perplexity: 2.6, 9435.2 tokens/sec on cpu()
// epoch: 308, perplexity: 2.5, 9773.2 tokens/sec on cpu()
// epoch: 309, perplexity: 2.5, 9982.3 tokens/sec on cpu()
// epoch: 310, perplexity: 2.4, 10054.4 tokens/sec on cpu()
// epoch: 311, perplexity: 2.5, 10319.0 tokens/sec on cpu()
// epoch: 312, perplexity: 2.3, 9329.2 tokens/sec on cpu()
// epoch: 313, perplexity: 2.4, 9366.9 tokens/sec on cpu()
// epoch: 314, perplexity: 2.4, 9975.2 tokens/sec on cpu()
// epoch: 315, perplexity: 2.2, 10154.4 tokens/sec on cpu()
// epoch: 316, perplexity: 2.3, 8887.2 tokens/sec on cpu()
// epoch: 317, perplexity: 2.2, 10644.7 tokens/sec on cpu()
// epoch: 318, perplexity: 2.2, 9669.6 tokens/sec on cpu()
// epoch: 319, perplexity: 2.1, 10515.9 tokens/sec on cpu()
// epoch: 320, perplexity: 2.2, 11599.9 tokens/sec on cpu()
// epoch: 321, perplexity: 2.1, 11626.3 tokens/sec on cpu()
// epoch: 322, perplexity: 2.0, 11593.4 tokens/sec on cpu()
// epoch: 323, perplexity: 2.1, 11624.3 tokens/sec on cpu()
// epoch: 324, perplexity: 2.0, 10831.9 tokens/sec on cpu()
// epoch: 325, perplexity: 1.9, 8638.8 tokens/sec on cpu()
// epoch: 326, perplexity: 2.0, 9488.7 tokens/sec on cpu()
// epoch: 327, perplexity: 2.0, 11375.1 tokens/sec on cpu()
// epoch: 328, perplexity: 1.9, 11376.8 tokens/sec on cpu()
// epoch: 329, perplexity: 1.9, 11571.9 tokens/sec on cpu()
// epoch: 330, perplexity: 1.8, 11642.7 tokens/sec on cpu()
// epoch: 331, perplexity: 1.9, 11524.1 tokens/sec on cpu()
// epoch: 332, perplexity: 1.8, 11507.7 tokens/sec on cpu()
// epoch: 333, perplexity: 1.7, 10946.5 tokens/sec on cpu()
// epoch: 334, perplexity: 1.6, 10845.8 tokens/sec on cpu()
// epoch: 335, perplexity: 1.6, 9969.1 tokens/sec on cpu()
// epoch: 336, perplexity: 1.8, 9088.7 tokens/sec on cpu()
// epoch: 337, perplexity: 1.8, 9285.0 tokens/sec on cpu()
// epoch: 338, perplexity: 1.6, 10405.7 tokens/sec on cpu()
// epoch: 339, perplexity: 1.6, 10259.0 tokens/sec on cpu()
// epoch: 340, perplexity: 1.5, 10063.7 tokens/sec on cpu()
// epoch: 341, perplexity: 1.6, 8802.7 tokens/sec on cpu()
// epoch: 342, perplexity: 1.7, 9979.0 tokens/sec on cpu()
// epoch: 343, perplexity: 1.6, 10959.1 tokens/sec on cpu()
// epoch: 344, perplexity: 1.6, 9329.7 tokens/sec on cpu()
// epoch: 345, perplexity: 1.5, 9691.4 tokens/sec on cpu()
// epoch: 346, perplexity: 1.4, 10756.5 tokens/sec on cpu()
// epoch: 347, perplexity: 1.4, 11209.1 tokens/sec on cpu()
// epoch: 348, perplexity: 1.4, 11131.8 tokens/sec on cpu()
// epoch: 349, perplexity: 1.4, 10369.7 tokens/sec on cpu()
// epoch: 350, perplexity: 1.4, 11393.0 tokens/sec on cpu()
// epoch: 351, perplexity: 1.6, 11167.3 tokens/sec on cpu()
// epoch: 352, perplexity: 1.6, 10798.1 tokens/sec on cpu()
// epoch: 353, perplexity: 1.5, 10056.0 tokens/sec on cpu()
// epoch: 354, perplexity: 1.4, 10098.0 tokens/sec on cpu()
// epoch: 355, perplexity: 1.3, 9871.6 tokens/sec on cpu()
// epoch: 356, perplexity: 1.3, 11557.8 tokens/sec on cpu()
// epoch: 357, perplexity: 1.3, 11560.3 tokens/sec on cpu()
// epoch: 358, perplexity: 1.2, 11271.9 tokens/sec on cpu()
// epoch: 359, perplexity: 1.2, 10421.8 tokens/sec on cpu()
// epoch: 360, perplexity: 1.2, 10721.7 tokens/sec on cpu()
// epoch: 361, perplexity: 1.2, 11154.9 tokens/sec on cpu()
// epoch: 362, perplexity: 1.4, 11437.5 tokens/sec on cpu()
// epoch: 363, perplexity: 1.5, 11389.8 tokens/sec on cpu()
// epoch: 364, perplexity: 1.4, 11610.8 tokens/sec on cpu()
// epoch: 365, perplexity: 1.3, 11682.0 tokens/sec on cpu()
// epoch: 366, perplexity: 1.2, 11607.2 tokens/sec on cpu()
// epoch: 367, perplexity: 1.2, 11422.9 tokens/sec on cpu()
// epoch: 368, perplexity: 1.2, 10135.4 tokens/sec on cpu()
// epoch: 369, perplexity: 1.2, 10594.0 tokens/sec on cpu()
// epoch: 370, perplexity: 1.2, 11145.2 tokens/sec on cpu()
// epoch: 371, perplexity: 1.1, 10294.3 tokens/sec on cpu()
// epoch: 372, perplexity: 1.1, 11471.3 tokens/sec on cpu()
// epoch: 373, perplexity: 1.1, 11367.3 tokens/sec on cpu()
// epoch: 374, perplexity: 1.1, 11234.4 tokens/sec on cpu()
// epoch: 375, perplexity: 1.1, 10992.9 tokens/sec on cpu()
// epoch: 376, perplexity: 1.2, 10009.2 tokens/sec on cpu()
// epoch: 377, perplexity: 1.4, 8427.5 tokens/sec on cpu()
// epoch: 378, perplexity: 1.4, 9548.7 tokens/sec on cpu()
// epoch: 379, perplexity: 1.4, 10547.0 tokens/sec on cpu()
// epoch: 380, perplexity: 1.3, 11470.3 tokens/sec on cpu()
// epoch: 381, perplexity: 1.2, 11351.9 tokens/sec on cpu()
// epoch: 382, perplexity: 1.2, 10089.8 tokens/sec on cpu()
// epoch: 383, perplexity: 1.1, 11278.4 tokens/sec on cpu()
// epoch: 384, perplexity: 1.1, 11519.4 tokens/sec on cpu()
// epoch: 385, perplexity: 1.1, 11492.1 tokens/sec on cpu()
// epoch: 386, perplexity: 1.1, 11612.9 tokens/sec on cpu()
// epoch: 387, perplexity: 1.1, 11549.0 tokens/sec on cpu()
// epoch: 388, perplexity: 1.1, 10841.6 tokens/sec on cpu()
// epoch: 389, perplexity: 1.1, 9014.7 tokens/sec on cpu()
// epoch: 390, perplexity: 1.1, 10090.2 tokens/sec on cpu()
// epoch: 391, perplexity: 1.1, 10500.5 tokens/sec on cpu()
// epoch: 392, perplexity: 1.1, 10074.9 tokens/sec on cpu()
// epoch: 393, perplexity: 1.1, 9614.7 tokens/sec on cpu()
// epoch: 394, perplexity: 1.1, 9524.4 tokens/sec on cpu()
// epoch: 395, perplexity: 1.1, 9748.5 tokens/sec on cpu()
// epoch: 396, perplexity: 1.1, 11183.8 tokens/sec on cpu()
// epoch: 397, perplexity: 1.1, 11510.7 tokens/sec on cpu()
// epoch: 398, perplexity: 1.2, 8509.1 tokens/sec on cpu()
// epoch: 399, perplexity: 1.3, 9024.2 tokens/sec on cpu()
// epoch: 400, perplexity: 1.3, 9928.6 tokens/sec on cpu()
// epoch: 401, perplexity: 1.3, 9245.8 tokens/sec on cpu()
// epoch: 402, perplexity: 1.2, 8522.2 tokens/sec on cpu()
// epoch: 403, perplexity: 1.1, 9779.8 tokens/sec on cpu()
// epoch: 404, perplexity: 1.1, 10633.6 tokens/sec on cpu()
// epoch: 405, perplexity: 1.1, 10493.2 tokens/sec on cpu()
// epoch: 406, perplexity: 1.1, 10400.3 tokens/sec on cpu()

// %% [markdown]
// ## Summary
//
// * Gated RNNs can better capture dependencies for sequences with large time step distances.
// * Reset gates help capture short-term dependencies in sequences.
// * Update gates help capture long-term dependencies in sequences.
// * GRUs contain basic RNNs as their extreme case whenever the reset gate is switched on. They can also skip subsequences by turning on the update gate.
//
//
// ## Exercises
//
// 1. Assume that we only want to use the input at time step $t'$ to predict the output at time step $t > t'$. What are the best values for the reset and update gates for each time step?
// 1. Adjust the hyperparameters and analyze the their influence on running time, perplexity, and the output sequence.
// 1. Compare runtime, perplexity, and the output strings for `rnn.RNN` and `rnn.GRU` implementations with each other.
// 1. What happens if you implement only parts of a GRU, e.g., with only a reset gate or only an update gate?
